# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ## Age family size

# %%
DATA = "customer_segmentation_data"
file_path = os.path.join(DATA, "df_test_normalised.csv")
df = pd.read_csv(file_path)

# %%
features = ['Age', 'Family_Size']
X = df[features]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
agg_clustering = AgglomerativeClustering(n_clusters=4)
df['Cluster'] = agg_clustering.fit_predict(X_scaled)

# %%
biggest_cluster = df['Cluster'].mode()[0]
print(f"Biggest cluster is cluster {biggest_cluster}")
# Out:
# Biggest cluster is cluster 1

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Age'], y=df['Family_Size'], hue=df['Cluster'], palette='viridis', s=100)
plt.title('Age / Family Size')
plt.xlabel('Age')
plt.ylabel('Family Size')
plt.legend(title='Cluster')
plt.show()

# %% [markdown]
# ## Export segmentation into separate file

# %%
df[['Age', 'Family_Size', 'Cluster']].to_csv(os.path.join("segmentation_results",'hac_segmentation_results_age_family_size.csv'), index=False)

# %% [markdown]
# ## Age Ever married

# %%
features = ['Age', 'Ever_Married']
X = df[features]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
agg_clustering = AgglomerativeClustering(n_clusters=4)
df['Cluster'] = agg_clustering.fit_predict(X_scaled)

# %%
biggest_cluster = df['Cluster'].mode()[0]
print(f"Biggest cluster is cluster {biggest_cluster}")
# Out:
# Biggest cluster is cluster 0

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Age'], y=df['Ever_Married'], hue=df['Cluster'], palette='viridis', s=100)
plt.title('Age / ever married')
plt.xlabel('Age')
plt.ylabel('Ever_Married')
plt.legend(title='Cluster')
plt.show()

# %%
df[['Age', 'Ever_Married', 'Cluster']].to_csv(os.path.join("segmentation_results",'hac_segmentation_results_age_ever_married.csv'), index=False)
